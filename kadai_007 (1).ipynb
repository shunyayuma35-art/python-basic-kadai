# %% [markdown]
# <a href="https://colab.research.google.com/github/shunyayuma35-art/git_challenge/blob/pull_request/kadai_007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
array = [
    "月曜日は晴れです",
    "火曜日は雨です",
    "水曜日は晴れです",
    "木曜日は晴れです",
    "金曜日は曇りです",
    "土曜日は曇りのち雨です",
    "日曜日は雷雨です"
]

print(array[2])  # 水曜日の天気
# Out:
# 水曜日は晴れです
